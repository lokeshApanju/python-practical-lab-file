# %%
text = input("Enter string: ")
print("tex is",text)
# Out:
# tex is Lokesh

# %%
vowels = "aeiouAEIOU"
count = sum(1 for ch in text if ch in vowels)

print("Number of vowels:", count)
# Out:
# Number of vowels: 2
