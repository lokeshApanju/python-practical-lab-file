# %% [markdown]
# # user-provided list and display the position

# %%
lst = [12, 45, 33, 21, 88]
item = int(input("Enter item to search: "))
# Out:
# iten to search is :  21

# %%
if item in lst:
    print(f"Item found at position {lst.index(item) + 1}")
else:
    print("Item not found.")
# Out:
# Item found at position 4
